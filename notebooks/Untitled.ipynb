# %%
from google.cloud import bigquery
from google.oauth2 import service_account

# %%
credentials = service_account.Credentials.from_service_account_file('../misc/gc_creds.json')

# %%
project_id = 'hadooplearning-222811'

# %%
client = bigquery.Client(credentials= credentials,project=project_id)

# %%
sql = "SELECT * FROM `bigquery-public-data.iowa_liquor_sales.sales` LIMIT 10"

# %%
query_job = client.query(sql)

# %%
rows = query_job.result()  # Waits for query to finish
data = []
for row in rows:
    data.append({k:v for k,v in row.items()})

# %%
pd.DataFrame(data)
# Out:
#   invoice_and_item_number        date store_number  \
# 0         INV-05755200003  2017-06-27         5124
# 1            S15914500015  2013-11-23         2651
# 2            S33615600002  2016-07-27         2625
# 3         INV-00065600035  2016-08-31         5003
# 4         INV-00030100038  2016-08-30         3628
# 5         INV-00048800040  2016-08-31         2551
# 6         INV-00038200003  2016-08-30         2665
# 7            S33757200021  2016-08-04         4829
# 8         INV-17319400006  2019-02-04         3910
# 9            S14082200127  2013-10-04         2515
#
#                           store_name                  address          city  \
# 0         Price Chopper  /  Johnston         5440 NW  86th St      Johnston
# 1                   Hy-Vee / Waverly         1311 4 STREET SW       WAVERLY
# 2         Hy-Vee Wine and Spirits #2       3301 W Kimberly Rd     Davenport
# 3                     Famous Liquors         2604 W Locust St     Davenport
# ...

# %%
result
# Out:
# 100

# %%
import pandas as pd
# pd.Series({k:v for k,v in a.items()})
